# %%
import pandas as pd

df = pd.read_csv("../data/WA_Fn-UseC_-Telco-Customer-Churn.csv")

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.dtypes
# Out:
# customerID              str
# gender                  str
# SeniorCitizen         int64
# Partner                 str
# Dependents              str
# tenure                int64
# PhoneService            str
# MultipleLines           str
# InternetService         str
# OnlineSecurity          str
# OnlineBackup            str
# DeviceProtection        str
# TechSupport             str
# StreamingTV             str
# StreamingMovies         str
# Contract                str
# PaperlessBilling        str
# PaymentMethod           str
# MonthlyCharges      float64
# TotalCharges            str
# Churn                   str
# dtype: object

# %%
df.iloc[400:430]
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 400  2277-AXSDC  Female              0      No         No      32
# 401  9442-JTWDL  Female              0      No         No      11
# 402  0979-PHULV    Male              0     Yes        Yes      69
# 403  3067-SVMTC  Female              0     Yes         No      68
# 404  5495-GPSRW    Male              0      No         No      20
# 405  7606-BPHHN    Male              0      No         No      72
# 406  4742-DRORA    Male              0     Yes        Yes      60
# 407  0111-KLBQG    Male              1     Yes        Yes      32
# 408  4800-VHZKI  Female              0      No         No       1
# 409  7989-CHGTL    Male              0      No         No       1
# 410  0334-GDDSO    Male              1      No         No       3
# 411  4163-NCJAK  Female              0     Yes         No      46
# 412  5233-AOZUF  Female              0     Yes         No      29
# 413  5973-EJGDP    Male              0      No         No      51
# 414  1996-DBMUS  Female              1     Yes         No      48
# 415  7916-VCCPB  Female              0     Yes        Yes      16
# 416  4686-GEFRM    Male              0     Yes         No      70
# 417  5249-QYHEX  Female              0     Yes        Yes      40
# 418  0578-SKVMF  Female              0     Yes        Yes      22
# 419  5564-NEMQO  Female              1      No         No       1
# 420  2233-FAGXV  Female              0     Yes        Yes       5
# 421  5605-IYGFG  Female              0      No         No       7
# 422  7663-ZTEGJ    Male              0      No        Yes      29
# 423  3935-TBRZZ    Male              0     Yes        Yes      44
# 424  8111-BKVDS  Female              0      No         No      10
# 425  2055-SIFSS  Female              1     Yes         No      55
# 426  2806-MLNTI    Male              1     Yes         No      52
# 427  8734-DKSTZ  Female              0     Yes        Yes      10
# 428  4360-PNRQB    Male              0      No         No      18
# 429  6152-ONASV  Female              0     Yes         No      68
#
#     PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 400          Yes                No              No  No internet service  ...
# 401          Yes                No              No  No internet service  ...
# 402          Yes               Yes     Fiber optic                   No  ...
# 403          Yes                No             DSL                  Yes  ...
# 404          Yes                No              No  No internet service  ...
# 405          Yes                No              No  No internet service  ...
# 406          Yes               Yes     Fiber optic                  Yes  ...
# 407          Yes                No     Fiber optic                   No  ...
# 408          Yes                No              No  No internet service  ...
# 409          Yes                No              No  No internet service  ...
# 410          Yes               Yes     Fiber optic                   No  ...
# 411          Yes               Yes              No  No internet service  ...
# 412          Yes               Yes     Fiber optic                   No  ...
# 413          Yes               Yes     Fiber optic                   No  ...
# 414          Yes                No     Fiber optic                   No  ...
# 415          Yes                No     Fiber optic                   No  ...
# 416          Yes               Yes     Fiber optic                   No  ...
# 417          Yes               Yes              No  No internet service  ...
# 418          Yes                No     Fiber optic                   No  ...
# 419          Yes                No     Fiber optic                   No  ...
# 420          Yes               Yes              No  No internet service  ...
# 421          Yes                No     Fiber optic                   No  ...
# 422          Yes               Yes     Fiber optic                   No  ...
# 423          Yes               Yes              No  No internet service  ...
# 424           No  No phone service             DSL                  Yes  ...
# 425          Yes               Yes             DSL                   No  ...
# 426          Yes               Yes     Fiber optic                   No  ...
# 427          Yes               Yes     Fiber optic                   No  ...
# 428          Yes               Yes     Fiber optic                   No  ...
# 429          Yes               Yes             DSL                  Yes  ...
#
#         DeviceProtection          TechSupport          StreamingTV  \
# 400  No internet service  No internet service  No internet service
# 401  No internet service  No internet service  No internet service
# 402                  Yes                   No                  Yes
# 403                   No                  Yes                   No
# 404  No internet service  No internet service  No internet service
# 405  No internet service  No internet service  No internet service
# 406                  Yes                   No                  Yes
# 407                   No                   No                  Yes
# 408  No internet service  No internet service  No internet service
# 409  No internet service  No internet service  No internet service
# 410                   No                   No                   No
# 411  No internet service  No internet service  No internet service
# 412                   No                   No                   No
# 413                  Yes                  Yes                   No
# 414                   No                   No                   No
# 415                   No                   No                   No
# 416                  Yes                  Yes                   No
# 417  No internet service  No internet service  No internet service
# 418                   No                   No                   No
# 419                  Yes                   No                   No
# 420  No internet service  No internet service  No internet service
# 421                   No                   No                   No
# 422                  Yes                  Yes                   No
# 423  No internet service  No internet service  No internet service
# 424                  Yes                   No                   No
# 425                   No                   No                   No
# 426                  Yes                   No                  Yes
# 427                   No                   No                   No
# 428                   No                   No                   No
# 429                   No                  Yes                   No
#
#          StreamingMovies        Contract PaperlessBilling  \
# 400  No internet service        One year               No
# 401  No internet service        One year               No
# 402                  Yes  Month-to-month              Yes
# 403                   No        One year               No
# 404  No internet service        Two year              Yes
# 405  No internet service        Two year              Yes
# 406                   No        One year              Yes
# 407                  Yes  Month-to-month              Yes
# 408  No internet service  Month-to-month              Yes
# 409  No internet service  Month-to-month              Yes
# 410                   No  Month-to-month              Yes
# 411  No internet service        One year              Yes
# 412                   No  Month-to-month              Yes
# 413                   No  Month-to-month              Yes
# 414                   No  Month-to-month              Yes
# 415                   No  Month-to-month               No
# 416                  Yes        Two year              Yes
# 417  No internet service        Two year              Yes
# 418                  Yes  Month-to-month               No
# 419                   No  Month-to-month              Yes
# 420  No internet service  Month-to-month              Yes
# 421                   No  Month-to-month              Yes
# 422                  Yes        One year               No
# 423  No internet service        One year               No
# 424                   No  Month-to-month               No
# 425                   No  Month-to-month               No
# 426                  Yes        One year              Yes
# 427                  Yes  Month-to-month               No
# 428                   No  Month-to-month              Yes
# 429                   No        One year               No
#
#                  PaymentMethod MonthlyCharges  TotalCharges Churn
# 400  Bank transfer (automatic)          19.75        624.15    No
# 401    Credit card (automatic)          20.05         237.7    No
# 402    Credit card (automatic)          99.45        7007.6   Yes
# 403  Bank transfer (automatic)          55.90        3848.8    No
# 404               Mailed check          19.70         419.4    No
# 405    Credit card (automatic)          19.80       1468.75    No
# 406  Bank transfer (automatic)          95.40          5812    No
# 407               Mailed check          93.95       2861.45    No
# 408               Mailed check          19.90          19.9   Yes
# 409               Mailed check          19.60          19.6   Yes
# 410           Electronic check          81.35         233.7   Yes
# 411  Bank transfer (automatic)          24.45       1066.15    No
# 412           Electronic check          74.95       2149.05    No
# 413           Electronic check          87.35          4473    No
# 414  Bank transfer (automatic)          70.65       3545.05    No
# 415  Bank transfer (automatic)          73.25       1195.75    No
# 416  Bank transfer (automatic)          98.70        6858.9    No
# 417               Mailed check          24.80        1024.7    No
# 418           Electronic check          83.30        1845.9   Yes
# 419  Bank transfer (automatic)          75.30          75.3   Yes
# 420               Mailed check          24.30        132.25    No
# 421  Bank transfer (automatic)          69.85        515.45    No
# 422    Credit card (automatic)         100.55       2830.45    No
# 423               Mailed check          25.70        1110.5    No
# 424  Bank transfer (automatic)          40.70         449.3    No
# 425  Bank transfer (automatic)          51.65       2838.55    No
# 426  Bank transfer (automatic)         105.10        5376.4    No
# 427           Electronic check          85.95         858.6    No
# 428  Bank transfer (automatic)          75.60       1395.05    No
# 429  Bank transfer (automatic)          58.25        3975.7    No
#
# [30 rows x 21 columns]

# %%
df["TotalCharges"] = pd.to_numeric(
    df["TotalCharges"],
    errors="coerce"
)

# %%
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True) * 100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x="Churn")

plt.title("Churn Distribution")
plt.show()

# %%
pd.crosstab(df["Contract"], df["Churn"], normalize="index")
# Out:
# Churn                 No       Yes
# Contract
# Month-to-month  0.572903  0.427097
# One year        0.887305  0.112695
# Two year        0.971681  0.028319

# %%
pd.crosstab(df["PaymentMethod"], df["Churn"], normalize="index")
# Out:
# Churn                            No       Yes
# PaymentMethod
# Bank transfer (automatic)  0.832902  0.167098
# Credit card (automatic)    0.847569  0.152431
# Electronic check           0.547146  0.452854
# Mailed check               0.808933  0.191067

# %%
pd.crosstab(df["InternetService"], df["Churn"], normalize="index")
# Out:
# Churn                  No       Yes
# InternetService
# DSL              0.810409  0.189591
# Fiber optic      0.581072  0.418928
# No               0.925950  0.074050

# %%
num_cols = ["tenure", "MonthlyCharges", "TotalCharges"]

df[num_cols].hist(figsize=(12,4))
plt.show()

# %%
df[num_cols].corr()
# Out:
#                  tenure  MonthlyCharges  TotalCharges
# tenure          1.00000        0.247900      0.825880
# MonthlyCharges  0.24790        1.000000      0.651065
# TotalCharges    0.82588        0.651065      1.000000
